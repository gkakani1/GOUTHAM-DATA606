# %% [markdown]
# <a href="https://colab.research.google.com/github/gkakani1/GOUTHAM-DATA606/blob/main/Code/EDA/echange_Rates_EDA/exchange_Rates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import re 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_exc = pd.read_excel('/content/drive/MyDrive/Capstone/Datasets/Exchange_Rates/Exchange_Rates.xlsx')

# %%
df_exc.head(10)
# Out:
#         Date  USD      INR
# 0 2022-03-26    1  76.1893
# 1 2022-03-25    1  76.1893
# 2 2022-03-24    1  76.4064
# 3 2022-03-23    1  76.4383
# 4 2022-03-22    1  76.1198
# 5 2022-03-21    1  76.2670
# 6 2022-03-20    1  76.1106
# 7 2022-03-19    1  76.1106
# 8 2022-03-18    1  76.1106
# 9 2022-03-17    1  75.8696

# %%
df_exc.USD.unique()
# Out:
# array([1])

# %%
df_exc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8483 entries, 0 to 8482
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    8483 non-null   datetime64[ns]
#  1   USD     8483 non-null   int64
#  2   INR     8483 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 198.9 KB

# %%
df_exc.describe()
# Out:
#           USD          INR
# count  8483.0  8483.000000
# mean      1.0    35.065167
# std       0.0    31.388674
# min       1.0     0.000000
# 25%       1.0     0.000000
# 50%       1.0    46.613700
# 75%       1.0    64.955500
# max       1.0    77.051000

# %%
type(df_exc['Date'])
# Out:
# pandas.core.series.Series

# %%
df_exc['Date'] = df_exc.Date.astype(str)
df_exc[["Year", "Month", "Day"]] = df_exc["Date"].str.split("-", expand = True)

# %%
df_exc.head()
# Out:
#          Date  USD      INR  Year Month Day
# 0  2022-03-26    1  76.1893  2022    03  26
# 1  2022-03-25    1  76.1893  2022    03  25
# 2  2022-03-24    1  76.4064  2022    03  24
# 3  2022-03-23    1  76.4383  2022    03  23
# 4  2022-03-22    1  76.1198  2022    03  22

# %%
df_exc['Year'].unique()
# Out:
# array(['2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007',
#        '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999'],
#       dtype=object)

# %%
a=['2021', '2020', '2019', '2018', '2017', '2016', '2015','2014', '2013', '2012', '2011']
df_exc = df_exc[df_exc['Year'].isin(a)]

# %%
df_exc['Year'].unique()
# Out:
# array(['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014',
#        '2013', '2012', '2011'], dtype=object)

# %%
df_exc.head(10)
# Out:
#           Date  USD      INR  Year Month Day
# 85  2021-12-31    1  74.3680  2021    12  31
# 86  2021-12-30    1  74.3405  2021    12  30
# 87  2021-12-29    1  74.6598  2021    12  29
# 88  2021-12-28    1  74.6920  2021    12  28
# 89  2021-12-27    1  74.9739  2021    12  27
# 90  2021-12-26    1  75.0066  2021    12  26
# 91  2021-12-25    1  75.0066  2021    12  25
# 92  2021-12-24    1  75.0066  2021    12  24
# 93  2021-12-23    1  75.2233  2021    12  23
# 94  2021-12-22    1  75.5747  2021    12  22

# %%
df_excfinal = df_exc.groupby(["Year","Month"])["INR"].mean(),

# %%
df_excfinal.describe()
# Out:
# count    132.000000
# mean      63.900359
# std        8.390225
# min       44.368860
# 25%       59.972861
# 50%       65.068869
# 75%       70.776215
# max       76.251620
# Name: INR, dtype: float64

# %%
df_excfinal = df_excfinal.reset_index()

# %%
df_excfinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    132 non-null    object
#  1   Month   132 non-null    object
#  2   INR     132 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 3.2+ KB

# %%
df_excfinal.head(15)
# Out:
#     Year Month        INR
# 0   2011    01  45.430458
# 1   2011    02  45.440321
# 2   2011    03  44.973729
# 3   2011    04  44.368860
# 4   2011    05  44.920116
# 5   2011    06  44.844533
# 6   2011    07  44.412777
# 7   2011    08  45.399487
# 8   2011    09  47.552070
# 9   2011    10  49.253942
# 10  2011    11  50.761630
# 11  2011    12  52.464777
# 12  2012    01  51.198390
# 13  2012    02  49.180469
# 14  2012    03  50.360045

# %%
plt.scatter

# %%
df_excfinal.plot.scatter(x="Year",y="INR")

# %%
dict1 = {"01":"January",	"02":"February","03":	"March","04":"April","05":"May",	"06":"June",	"07":"July",	"08":"August",	"09":"September",	"10":"October",	"11":"November",	"12":"December"}

# %%
df_excfinal = df_excfinal.replace({"Month":dict1})

# %%
df_excfinal.head(15)
# Out:
#     Year      Month        INR
# 0   2011    January  45.430458
# 1   2011   February  45.440321
# 2   2011      March  44.973729
# 3   2011      April  44.368860
# 4   2011        May  44.920116
# 5   2011       June  44.844533
# 6   2011       July  44.412777
# 7   2011     August  45.399487
# 8   2011  September  47.552070
# 9   2011    October  49.253942
# 10  2011   November  50.761630
# 11  2011   December  52.464777
# 12  2012    January  51.198390
# 13  2012   February  49.180469
# 14  2012      March  50.360045

# %%
#df_excfinal.to_excel(r'/content/drive/MyDrive/Capstone/Datasets/Final_Datasets/Final_Exchange_Rates.xlsx', index = False)
