# %% [markdown]
# <a href="https://colab.research.google.com/github/gkakani1/GOUTHAM-DATA606/blob/main/Code/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Mounting Google Drive files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing required modules and libraries
import glob
import pandas as pd

# %%
path = "/content/drive/MyDrive/Capstone/Datasets/Vegtables/"

# %%
# Using glob module to return the fies in Vegetable directory
files = glob.glob(path+"*")

# %%
print(files)
# Out:
# ['/content/drive/MyDrive/Capstone/Datasets/Vegtables/Bitter Gourd', '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Brinjal', '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Cabbage', '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Cauliflower', '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Green Chillies', '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Okra', '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Onion', '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Peas', '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Tomato Hybrid', '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Tomato Local']

# %%
#No:of files in the directory
len(files)
# Out:
# 10

# %%
xlsx_files= []

# %%
# Appending the paths of each excel file from all the 10 foleders in Vegetable directory
for i in range(0,10):
  file1 = glob.glob(files[i]+"/*")
  xlsx_files.append(file1)

# %%
len(xlsx_files)
# Out:
# 10

# %%
# No:of excel files in each folder 
for i in range(0,len(xlsx_files)):
  print(len(xlsx_files[i]))
# Out:
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11

# %%
# List of files
xlsx_files
# Out:
# [['/content/drive/MyDrive/Capstone/Datasets/Vegtables/Bitter Gourd/BG 2011.xls.xlsx',
#   '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Bitter Gourd/BG 2012.xlsx',
#   '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Bitter Gourd/Bg 2013.xls.xlsx',
#   '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Bitter Gourd/BG 2014.xls.xlsx',
#   '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Bitter Gourd/BG 2015.xls.xlsx',
#   '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Bitter Gourd/BG 2016.xls.xlsx',
#   '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Bitter Gourd/BG 2017.xls.xlsx',
#   '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Bitter Gourd/BG 2018.xls.xlsx',
#   '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Bitter Gourd/BG 2020.xls.xlsx',
#   '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Bitter Gourd/BG 2019.xls.xlsx',
#   '/content/drive/MyDrive/Capstone/Datasets/Vegtables/Bitter Gourd/BG 2021.xls.xlsx'],
# ...

# %%
# Loading a sample excel file into a dataframe
df1  = pd.read_excel(xlsx_files[0][0])

# %%
# Sample DataFrame
df1
# Out:
#    Report Name : Monthwise Annual Price & Arrival Report  ...    Unnamed: 37
# 0                           Current Date : 07/02/2022     ...            NaN
# 1                                Selected Year : 2011     ...            NaN
# 2                          Crop Category : VEGETABLES     ...            NaN
# 3                            Crop Name : BITTER GOURD     ...            NaN
# 4                         Variety Name : BITTER GOURD     ...            NaN
# 5                                                 NaN     ...            NaN
# 6                                                 NaN     ...            NaN
# 7                                               S.No.     ...  Total Arrival
# 8                                                   1     ...              0
# 9                                                   2     ...              0
# 10                                                  3     ...             87
# ...

# %%
#  Checking number of rows and columns in each dataframe
list_row = []
list_col = []

for i in range(0,10):
  list_row1 = []
  list_col1 = []
  for j in range(0,11):
    df2 = pd.read_excel(xlsx_files[i][j])

    list_row1.append(len(df2))
    list_col1.append(len(df2.columns))
    
  list_row.append(list_row1)
  list_col.append(list_col1)

# %%
list_row
# Out:
# [[35, 35, 33, 33, 32, 32, 36, 35, 29, 34, 30],
#  [25, 27, 29, 29, 29, 25, 28, 28, 29, 29, 28],
#  [37, 36, 36, 37, 35, 34, 25, 25, 35, 25, 32],
#  [32, 37, 37, 36, 36, 34, 35, 35, 35, 36, 35],
#  [34, 34, 35, 37, 36, 37, 32, 35, 35, 36, 36],
#  [36, 32, 36, 31, 35, 34, 36, 33, 36, 33, 35],
#  [32, 37, 37, 38, 37, 37, 37, 37, 38, 36, 37],
#  [33, 32, 31, 31, 31, 27, 32, 34, 32, 36, 35],
#  [33, 35, 35, 38, 36, 36, 38, 35, 38, 36, 37],
#  [24, 24, 26, 27, 29, 28, 30, 31, 25, 29, 29]]

# %%
max1 = 0
for l in list_row:
  max1 = max(max1,max(l))

# %%
# Maximum number of rows of an excel file among all the files present 
max1
# Out:
# 38

# %%
list_col
# Out:
# [[38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38],
#  [38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38],
#  [38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38],
#  [38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38],
#  [38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38],
#  [38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38],
#  [38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38],
#  [38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38],
#  [38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38],
#  [38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38]]

# %%
max(list_col)
# Out:
# [38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38]

# %%
# All the datasets consists of 38 columns

# %%
# List of all the unique states present in entire vegetebale datasets 
list_states = []
for i in range(0,10):
  for j in range(0,11):
    df3 = pd.read_excel(xlsx_files[i][j])
    for a in list(df3['Unnamed: 1']):
      if a not in list_states:
        list_states.append(a)

# %%
list_states
# Out:
# [nan,
#  'Center Name',
#  'AHMEDABAD / अहमदाबाद',
#  'AMRITSAR / अमृतसर',
#  'BANGALURU / बेंगलुरू',
#  'BARAUT / बड़ौत',
#  'BHOPAL / भोपाल',
#  'BHUBANESHWAR / भुबनेश्वर',
#  'CHANDIGARH / चंडीगढ़',
#  'CHENNAI / चेन्नई',
#  'DEHRADUN / देहरादून',
#  'DELHI / दिल्ली',
#  'GANGATOK / गंगटोक',
#  'GUWAHATI / गुवाहाटी',
#  'HYDERABAD / हैदराबाद',
#  'JAIPUR / जयपुर',
#  'JAMMU / जम्मू',
#  'KOLKATA / कोलकाता',
#  'LUCKNOW / लखनऊ',
#  'MUMBAI / मुंबई',
#  'NAGPUR / नागपुर',
#  'NASIK / नाशिक',
#  'PATNA / पटना',
#  'PUNE / पुणे',
#  'RAIPUR / रायपुर',
#  'RANCHI / रांची',
#  'SHIMLA / शिमला',
#  'SRINAGAR / श्रीनगर',
#  'TRIVENDRUM / त्रिवेन्द्रम',
#  'PIMPALGAON / पिंपलगाँव',
#  'VARANASI / वाराणसी',
#  'VIJAYAWADA / विजयवाड़ा',
#  'AHMEDABAD / à¤…à¤¹à¤®à¤¦à¤¾à¤¬à¤¾à¤¦',
#  'BHOPAL / à¤\xadà¥‹à¤ªà¤¾à¤²',
#  'BHUBANESHWAR / à¤\xadà¥\x81à¤¬à¤¨à¥‡à¤¶à¥\x8dà¤µà¤°',
#  'CHENNAI / à¤šà¥‡à¤¨à¥\x8dà¤¨à¤ˆ',
#  'DELHI / à¤¦à¤¿à¤²à¥\x8dà¤²à¥€',
#  'GANGATOK / à¤—à¤‚à¤—à¤Ÿà¥‹à¤•',
# ...

# %%
len(list_states)
# Out:
# 55

# %%
# There are 55 different city names 
# India consists of 28 states and 7 union teritories 
# So the data might be collected from different places in a single state in different years

# %%
# Viewing the combined dataframe 
df_original = pd.DataFrame()
for i in range(0,10):
  for j in range(0,11):
    df_i = pd.read_excel(xlsx_files[i][j])
    df_original = df_original.append(df_i, ignore_index = True)

# %%
df_original
# Out:
#      Report Name : Monthwise Annual Price & Arrival Report  ... Unnamed: 37
# 0                             Current Date : 07/02/2022     ...         NaN
# 1                                  Selected Year : 2011     ...         NaN
# 2                            Crop Category : VEGETABLES     ...         NaN
# 3                              Crop Name : BITTER GOURD     ...         NaN
# 4                           Variety Name : BITTER GOURD     ...         NaN
# ...                                                 ...     ...         ...
# 3630                                                 17     ...        3770
# 3631                                                 18     ...          30
# 3632                                                 19     ...           0
# 3633                                                 20     ...         718
# 3634                                                 21     ...           0
#
# [3635 rows x 38 columns]

# %%
# Cheking sample dataframe of an individual excel file
df_sam = pd.read_excel(xlsx_files[0][0])

# %%
df_sam
# Out:
#    Report Name : Monthwise Annual Price & Arrival Report  ...    Unnamed: 37
# 0                           Current Date : 07/02/2022     ...            NaN
# 1                                Selected Year : 2011     ...            NaN
# 2                          Crop Category : VEGETABLES     ...            NaN
# 3                            Crop Name : BITTER GOURD     ...            NaN
# 4                         Variety Name : BITTER GOURD     ...            NaN
# 5                                                 NaN     ...            NaN
# 6                                                 NaN     ...            NaN
# 7                                               S.No.     ...  Total Arrival
# 8                                                   1     ...              0
# 9                                                   2     ...              0
# 10                                                  3     ...             87
# ...

# %%
Or_rows = len(df_sam)

# %% [markdown]
# # Organising an individual dataset

# %%
#) Adding an extra set of columns ["Crop" & "Year"] to the dataframe
year = df_sam.iat[1,0]
df_sam.insert(38, "Year", year[-4:])
Crop_variety = df_sam.iat[4,0]
df_sam.insert(38, "Crop", Crop_variety[14:])

# %%
# Removing the first 6 unwanted rows
df_sam1 = df_sam.iloc[6:,:,]

# %%
df_sam1
# Out:
#    Report Name : Monthwise Annual Price & Arrival Report  ...  Year
# 6                                                 NaN     ...  2011
# 7                                               S.No.     ...  2011
# 8                                                   1     ...  2011
# 9                                                   2     ...  2011
# 10                                                  3     ...  2011
# 11                                                  4     ...  2011
# 12                                                  5     ...  2011
# 13                                                  6     ...  2011
# 14                                                  7     ...  2011
# 15                                                  8     ...  2011
# 16                                                  9     ...  2011
# 17                                                 10     ...  2011
# 18                                                 11     ...  2011
# ...

# %%
# Total no:of columns present
len(df_sam1.columns)
# Out:
# 40

# %%
# Selecting required columns from the entire dataframe
# I am deleting both avg retail price and total arrival columns 
list1 = [0,1,2,38,39]
for i in range(1,12):
  list1.append(((i)*(3))+2)
list2 = list(range(0,40))

# %%
for i in list1:
  if i in list2:
    list2.remove(i)

# %%
# Dropping unnecessary columns
df_sam1 = df_sam1.drop(df_sam1.columns[list2],axis=1)

# %%
# Number of rows present 
len(df_sam1)
# Out:
# 29

# %%
# Number of columns
len(df_sam1.columns)
# Out:
# 16

# %%
# Selecting header values from the cells 
head_list = df_sam1.iloc[1,0:2].values.tolist()

# %%
head_list
# Out:
# ['S.No.', 'Center Name']

# %%
list2 = df_sam1.iloc[0,2:14].values.tolist()

# %%
list2
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %%
list2 = ["Price in "+x for x in list2]

# %%
head_list = head_list + list2

# %%
head_list
# Out:
# ['S.No.',
#  'Center Name',
#  'Price in January',
#  'Price in February',
#  'Price in March',
#  'Price in April',
#  'Price in May',
#  'Price in June',
#  'Price in July',
#  'Price in August',
#  'Price in September',
#  'Price in October',
#  'Price in November',
#  'Price in December']

# %%
head_list = head_list + df_sam1.columns.values.tolist()[-2:]

# %%
# Final organised header values 
head_list
# Out:
# ['S.No.',
#  'Center Name',
#  'Price in January',
#  'Price in February',
#  'Price in March',
#  'Price in April',
#  'Price in May',
#  'Price in June',
#  'Price in July',
#  'Price in August',
#  'Price in September',
#  'Price in October',
#  'Price in November',
#  'Price in December',
#  'Crop',
#  'Year']

# %%
df_sam1.columns = head_list

# %%
# Modified dataframe
df_sam1
# Out:
#     S.No.                Center Name  ...           Crop  Year
# 6     NaN                        NaN  ...   BITTER GOURD  2011
# 7   S.No.                Center Name  ...   BITTER GOURD  2011
# 8       1       AHMEDABAD / अहमदाबाद  ...   BITTER GOURD  2011
# 9       2          AMRITSAR / अमृतसर  ...   BITTER GOURD  2011
# 10      3       BANGALURU / बेंगलुरू  ...   BITTER GOURD  2011
# 11      4              BARAUT / बड़ौत  ...   BITTER GOURD  2011
# 12      5             BHOPAL / भोपाल  ...   BITTER GOURD  2011
# 13      6   BHUBANESHWAR / भुबनेश्वर  ...   BITTER GOURD  2011
# 14      7        CHANDIGARH / चंडीगढ़  ...   BITTER GOURD  2011
# 15      8           CHENNAI / चेन्नई  ...   BITTER GOURD  2011
# 16      9        DEHRADUN / देहरादून  ...   BITTER GOURD  2011
# 17     10             DELHI / दिल्ली  ...   BITTER GOURD  2011
# 18     11          GANGATOK / गंगटोक  ...   BITTER GOURD  2011
# 19     12        GUWAHATI / गुवाहाटी  ...   BITTER GOURD  2011
# ...

# %%
# Removing Unwanted rows
df_sam1 = df_sam1.drop(labels=[6,7],axis = 0)

# %%
# Re_setting the index values
df_sam1= df_sam1.reset_index(drop= True)

# %%
# Final Dataframe
df_sam1
# Out:
#    S.No.                Center Name  ...           Crop  Year
# 0      1       AHMEDABAD / अहमदाबाद  ...   BITTER GOURD  2011
# 1      2          AMRITSAR / अमृतसर  ...   BITTER GOURD  2011
# 2      3       BANGALURU / बेंगलुरू  ...   BITTER GOURD  2011
# 3      4              BARAUT / बड़ौत  ...   BITTER GOURD  2011
# 4      5             BHOPAL / भोपाल  ...   BITTER GOURD  2011
# 5      6   BHUBANESHWAR / भुबनेश्वर  ...   BITTER GOURD  2011
# 6      7        CHANDIGARH / चंडीगढ़  ...   BITTER GOURD  2011
# 7      8           CHENNAI / चेन्नई  ...   BITTER GOURD  2011
# 8      9        DEHRADUN / देहरादून  ...   BITTER GOURD  2011
# 9     10             DELHI / दिल्ली  ...   BITTER GOURD  2011
# 10    11          GANGATOK / गंगटोक  ...   BITTER GOURD  2011
# 11    12        GUWAHATI / गुवाहाटी  ...   BITTER GOURD  2011
# 12    13       HYDERABAD / हैदराबाद  ...   BITTER GOURD  2011
# 13    14             JAIPUR / जयपुर  ...   BITTER GOURD  2011
# ...

# %%
len(df_sam1.columns)
# Out:
# 16

# %%
fin_rows= len(df_sam1)

# %%
del_rows = Or_rows-fin_rows

# %%
# Number of rows deleted
del_rows
# Out:
# 8

# %%
# Loading individual excel files into a seperate datframes 
# Organising each dataframe using the above steps 
# Combining the individual dataframes into a df_final dataframe
df_final = pd.DataFrame()
list1 = [0,1,2,38,39]
for i in range(1,12):
  list1.append(((i)*(3))+2)
list_rem = list(range(0,40))
for i in list1:
  if i in list_rem:
    list_rem.remove(i)
for i in range(0,10):
  for j in range(0,11):
    df_i = pd.read_excel(xlsx_files[i][j])
    year = df_i.iat[1,0]
    df_i.insert(38, "Year", year[-4:])
    Crop_variety = df_i.iat[4,0]
    df_i.insert(38, "Crop", Crop_variety[14:])
    df_i = df_i.iloc[6:,:,]
    df_i = df_i.drop(df_i.columns[list_rem],axis=1)
    head_list = df_i.iloc[1,0:2].values.tolist()
    list2 = df_i.iloc[0,2:14].values.tolist()
    list2 = ["Price in "+x for x in list2]
    head_list = head_list + list2
    head_list = head_list + df_i.columns.values.tolist()[-2:]
    df_i.columns = head_list
    df_i = df_i.drop(labels=[6,7],axis = 0)
    df_i= df_i.reset_index(drop= True)
    df_final = df_final.append(df_i, ignore_index = True)

# %%
# Final Combined dataframe
df_final
# Out:
#      S.No.                Center Name  ...           Crop  Year
# 0        1       AHMEDABAD / अहमदाबाद  ...   BITTER GOURD  2011
# 1        2          AMRITSAR / अमृतसर  ...   BITTER GOURD  2011
# 2        3       BANGALURU / बेंगलुरू  ...   BITTER GOURD  2011
# 3        4              BARAUT / बड़ौत  ...   BITTER GOURD  2011
# 4        5             BHOPAL / भोपाल  ...   BITTER GOURD  2011
# ...    ...                        ...  ...            ...   ...
# 2750    17               PATNA / पटना  ...   TOMATO LOCAL  2012
# 2751    18                PUNE / पुणे  ...   TOMATO LOCAL  2012
# 2752    19            RAIPUR / रायपुर  ...   TOMATO LOCAL  2012
# 2753    20             RANCHI / रांची  ...   TOMATO LOCAL  2012
# 2754    21  TRIVENDRUM / त्रिवेन्द्रम  ...   TOMATO LOCAL  2012
#
# [2755 rows x 16 columns]

# %%
len(df_final.columns) == len(df_sam1.columns)
# Out:
# True

# %%
# Number of columns are as expected

# %%
len(df_final)
# Out:
# 2755

# %%
list_row
# Out:
# [[35, 35, 33, 33, 32, 32, 36, 35, 29, 34, 30],
#  [25, 27, 29, 29, 29, 25, 28, 28, 29, 29, 28],
#  [37, 36, 36, 37, 35, 34, 25, 25, 35, 25, 32],
#  [32, 37, 37, 36, 36, 34, 35, 35, 35, 36, 35],
#  [34, 34, 35, 37, 36, 37, 32, 35, 35, 36, 36],
#  [36, 32, 36, 31, 35, 34, 36, 33, 36, 33, 35],
#  [32, 37, 37, 38, 37, 37, 37, 37, 38, 36, 37],
#  [33, 32, 31, 31, 31, 27, 32, 34, 32, 36, 35],
#  [33, 35, 35, 38, 36, 36, 38, 35, 38, 36, 37],
#  [24, 24, 26, 27, 29, 28, 30, 31, 25, 29, 29]]

# %%
sum1 = 0
for i in list_row:
  sum1 = sum1+sum(i)

# %%
# Same as expected no:of columns 
sum1  == (len(df_final))+(8)*(10)*(11)
# Out:
# True
